# %% [markdown]
# <a href="https://colab.research.google.com/github/xszc0123/physics/blob/20250522/2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 원심력의 이해 - 커브길 버스 속에서 기울어지는 현상

# %%
import math

g = 9.80

ac = g
print(ac, "m/s*s")
# Out:
# 9.8 m/s*s
